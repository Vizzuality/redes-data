# %% [markdown]
# <img width="600" height="200" src="../../datasets/redes.png">

# %% [markdown]
# # Images
# ## Purpose
# The purpose of this notebook is to create images from Earth Engine datasets.
#
# ## Setup
# ### Library import

# %%
import os
from ipywidgets import interact
import matplotlib.pyplot as plt

from vizzDL import images

# %% [markdown]
# ## **Create image**
# **Create `images` object**

# %%
image = images.Composite()

# %% [markdown]
# **Select region**

# %%
geometry = {'type': 'FeatureCollection',
 'features': [{'type': 'Feature',
   'properties': {},
   'geometry': {'type': 'Polygon',
    'coordinates': [[[17.612549, -14.719569],
      [17.612549, -14.599695],
      [17.757939, -14.599695],
      [17.757939, -14.719569],
      [17.612549, -14.719569]]]}}]}

# %%
#image.select_region(slug="Landsat-8-Surface-Reflectance", init_date='2019-01-01', end_date='2019-12-31', lat=46.056, lon=-122.1149, zoom=10)
image.select_region(slug="SRTM-Digital-Elevation", init_date='2019-01-01', end_date='2019-12-31', lat=46.056, lon=-122.1149, zoom=10)
# Out:
# Draw a rectangle on map to select and area.
# Map(center=[46.056, -122.1149], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'z…

# %% [markdown]
# ### Image
# **Create image as a Numpy array**

# %%
array = image.image_as_array()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 array = image.image_as_array()
#
# File /tf/notebooks/Lab/vizzDL/images.py:152, in Composite.image_as_array(self, dimensions, alpha_channel)
#     150     self.image = array[:,:,:,:4]
#     151 else:
# --> 152     self.image = array[:,:,:,:3]
#     154 return self.image
#
# IndexError: too many indices for array: array is 3-dimensional, but 4 were indexed

# %%
fig, ax = plt.subplots(figsize=(10,10))

ax.imshow(array[0,:,:,:])
ax.set_title('LR')

plt.show()

# %% [markdown]
# ### Save `GeoTIFF`

# %%
image.save_as_GeoTIFF(folder_path = '../../datasets/processed/GeoTIFFs/', region_name = 'Saint_Helens')
